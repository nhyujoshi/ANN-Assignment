# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
# Load the data
train_df = pd.read_csv('/Masters/ANN/Assignment/IMDB Movie Review/train.tsv', sep='\t')
test_df = pd.read_csv('/Masters/ANN/Assignment/IMDB Movie Review/test.tsv', sep='\t')

# %%
# Load stopwords
with open('/Masters/ANN/Assignment/IMDB Movie Review/stopwords.txt', 'r') as f:
    stopwords = set(f.read().splitlines())

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nhyuj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nhyuj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\nhyuj\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Function to get the part of speech tag for lemmatization
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {
        'J': wordnet.ADJ,
        'N': wordnet.NOUN,
        'V': wordnet.VERB,
        'R': wordnet.ADV
    }
    return tag_dict.get(tag, wordnet.NOUN)

# %%
# Text preprocessing function
def preprocess_text(text):
    # Remove special characters and lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text).lower()
    # Tokenize
    words = word_tokenize(text)
    # Remove stopwords and lemmatize
    words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words if word not in stopwords]
    return ' '.join(words)

# %%
example = "I don't like this movie, it doesn't make sense. he won't watch it again in 2024 @ !"
print(preprocess_text(example))
# Out:
# dont like doesnt make sense wont watch

# %%
from tqdm import tqdm
tqdm.pandas()

# Apply preprocessing
train_df['cleaned_review'] = train_df['review'].progress_apply(preprocess_text)
test_df['cleaned_review'] = test_df['review'].progress_apply(preprocess_text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 32745/32745 [19:14<00:00, 28.37it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2681/2681 [01:06<00:00, 40.42it/s]

# %%
# Tokenize the cleaned reviews
tokenizer = Tokenizer(num_words=10000)  # Use the top 10,000 words
tokenizer.fit_on_texts(train_df['cleaned_review'])

# Convert text to sequences
train_sequences = tokenizer.texts_to_sequences(train_df['cleaned_review'])
test_sequences = tokenizer.texts_to_sequences(test_df['cleaned_review'])

# Define maximum sequence length
max_length = 200

# Pad the sequences to ensure uniform length
X_train = pad_sequences(train_sequences, maxlen=max_length)
X_test = pad_sequences(test_sequences, maxlen=max_length)

# %%
# Encode sentiment labels to integers
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['sentiment'])
y_test = label_encoder.transform(test_df['sentiment'])

# One-hot encode the labels
y_train = to_categorical(y_train, num_classes=3)
y_test = to_categorical(y_test, num_classes=3)

# %%
# Load GloVe embeddings
embedding_index = {}
with open('glove.6B.100d.txt', 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs

# Prepare embedding matrix
embedding_dim = 100
word_index = tokenizer.word_index
num_words = min(len(word_index) + 1, 10000)
embedding_matrix = np.zeros((num_words, embedding_dim))

for word, i in word_index.items():
    if i >= 10000:
        continue
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Define the model
# Define the model with a single LSTM layer
model = Sequential([
    Embedding(input_dim=num_words, 
              output_dim=embedding_dim,  
              weights=[embedding_matrix], 
              trainable=False),
    LSTM(64),
    Dropout(0.7),
    Dense(3, activation='softmax')  # Output layer with 3 classes
])

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.4)
# Out:
# Epoch 1/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 79ms/step - accuracy: 0.4311 - loss: 1.0573 - val_accuracy: 0.5572 - val_loss: 0.9153
# Epoch 2/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - accuracy: 0.5471 - loss: 0.9340 - val_accuracy: 0.5769 - val_loss: 0.8870
# Epoch 3/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.5729 - loss: 0.8898 - val_accuracy: 0.5705 - val_loss: 0.8869
# Epoch 4/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - accuracy: 0.5832 - loss: 0.8762 - val_accuracy: 0.6013 - val_loss: 0.8496
# Epoch 5/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - accuracy: 0.6018 - loss: 0.8508 - val_accuracy: 0.6115 - val_loss: 0.8300
# Epoch 6/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 32s 103ms/step - accuracy: 0.6096 - loss: 0.8366 - val_accuracy: 0.6173 - val_loss: 0.8198
# Epoch 7/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.6252 - loss: 0.8221 - val_accuracy: 0.6215 - val_loss: 0.8126
# Epoch 8/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.6260 - loss: 0.8111 - val_accuracy: 0.6248 - val_loss: 0.8095
# Epoch 9/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.6351 - loss: 0.7953 - val_accuracy: 0.6255 - val_loss: 0.8041
# Epoch 10/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.6465 - loss: 0.7845 - val_accuracy: 0.6162 - val_loss: 0.8154
# Epoch 11/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step - accuracy: 0.6415 - loss: 0.7793 - val_accuracy: 0.6204 - val_loss: 0.8048
# Epoch 12/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.6564 - loss: 0.7617 - val_accuracy: 0.6238 - val_loss: 0.8083
# Epoch 13/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.6531 - loss: 0.7617 - val_accuracy: 0.6237 - val_loss: 0.8272
# Epoch 14/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.6672 - loss: 0.7413 - val_accuracy: 0.6270 - val_loss: 0.7974
# Epoch 15/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step - accuracy: 0.6704 - loss: 0.7367 - val_accuracy: 0.6309 - val_loss: 0.8148
# Epoch 16/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 83ms/step - accuracy: 0.6733 - loss: 0.7187 - val_accuracy: 0.6189 - val_loss: 0.8123
# Epoch 17/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 92ms/step - accuracy: 0.6717 - loss: 0.7140 - val_accuracy: 0.6252 - val_loss: 0.8149
# Epoch 18/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.6863 - loss: 0.6994 - val_accuracy: 0.6271 - val_loss: 0.8191
# Epoch 19/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step - accuracy: 0.6943 - loss: 0.6895 - val_accuracy: 0.6193 - val_loss: 0.8154
# Epoch 20/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.7061 - loss: 0.6733 - val_accuracy: 0.6231 - val_loss: 0.8345
# Epoch 21/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.7167 - loss: 0.6603 - val_accuracy: 0.6242 - val_loss: 0.8240
# Epoch 22/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step - accuracy: 0.6997 - loss: 0.6741 - val_accuracy: 0.6267 - val_loss: 0.8422
# Epoch 23/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.7213 - loss: 0.6395 - val_accuracy: 0.6269 - val_loss: 0.8501
# Epoch 24/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.7232 - loss: 0.6408 - val_accuracy: 0.6242 - val_loss: 0.8369
# Epoch 25/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.7260 - loss: 0.6202 - val_accuracy: 0.6275 - val_loss: 0.8519
# Epoch 26/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.7444 - loss: 0.5962 - val_accuracy: 0.6142 - val_loss: 0.8643
# Epoch 27/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.7468 - loss: 0.5904 - val_accuracy: 0.6162 - val_loss: 0.8861
# Epoch 28/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.7511 - loss: 0.5807 - val_accuracy: 0.6180 - val_loss: 0.9532
# Epoch 29/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.7513 - loss: 0.5702 - val_accuracy: 0.6093 - val_loss: 0.8892
# Epoch 30/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 30s 97ms/step - accuracy: 0.7654 - loss: 0.5575 - val_accuracy: 0.6171 - val_loss: 0.8976
# Epoch 31/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 83ms/step - accuracy: 0.7669 - loss: 0.5528 - val_accuracy: 0.6150 - val_loss: 0.9702
# Epoch 32/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step - accuracy: 0.7783 - loss: 0.5315 - val_accuracy: 0.6070 - val_loss: 0.9329
# Epoch 33/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.7760 - loss: 0.5416 - val_accuracy: 0.6066 - val_loss: 1.0124
# Epoch 34/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.7832 - loss: 0.5138 - val_accuracy: 0.6065 - val_loss: 0.9808
# Epoch 35/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.7933 - loss: 0.5021 - val_accuracy: 0.6026 - val_loss: 0.9951
# Epoch 36/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.7741 - loss: 0.5401 - val_accuracy: 0.6134 - val_loss: 0.9289
# Epoch 37/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.7916 - loss: 0.5045 - val_accuracy: 0.6093 - val_loss: 1.0003
# Epoch 38/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.7998 - loss: 0.4888 - val_accuracy: 0.6027 - val_loss: 1.0564
# Epoch 39/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.7928 - loss: 0.4991 - val_accuracy: 0.6110 - val_loss: 1.0133
# Epoch 40/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.8136 - loss: 0.4552 - val_accuracy: 0.5984 - val_loss: 1.1192
# Epoch 41/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.8202 - loss: 0.4508 - val_accuracy: 0.5962 - val_loss: 1.1749
# Epoch 42/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.8104 - loss: 0.4656 - val_accuracy: 0.6033 - val_loss: 1.1683
# Epoch 43/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.8286 - loss: 0.4314 - val_accuracy: 0.6061 - val_loss: 1.1572
# Epoch 44/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.8338 - loss: 0.4195 - val_accuracy: 0.6017 - val_loss: 1.1492
# Epoch 45/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.8423 - loss: 0.4041 - val_accuracy: 0.6053 - val_loss: 1.2860
# Epoch 46/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.8427 - loss: 0.3989 - val_accuracy: 0.5970 - val_loss: 1.1673
# Epoch 47/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.8418 - loss: 0.4051 - val_accuracy: 0.5993 - val_loss: 1.2487
# Epoch 48/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.8442 - loss: 0.3963 - val_accuracy: 0.5954 - val_loss: 1.0640
# Epoch 49/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.8277 - loss: 0.4202 - val_accuracy: 0.5919 - val_loss: 1.2500
# Epoch 50/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step - accuracy: 0.8521 - loss: 0.3768 - val_accuracy: 0.5880 - val_loss: 1.2294

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5208 - loss: 1.4994
# Test Accuracy: 0.5144

# %%
import matplotlib.pyplot as plt

# Extract loss and accuracy from history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Plot training & validation loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Predict sentiment for new reviews
new_reviews = ["This movie was fantastic! I loved it.", "The plot was boring and predictable.", "The movie was alright. I didn't like the romance but the action was okay."]
new_sequences = tokenizer.texts_to_sequences(new_reviews)
new_padded_sequences = pad_sequences(new_sequences, maxlen=max_length)

# Predict the sentiments
predictions = model.predict(new_padded_sequences)
predicted_labels = label_encoder.inverse_transform(predictions.argmax(axis=1))

print(predicted_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# [2 0 1]
